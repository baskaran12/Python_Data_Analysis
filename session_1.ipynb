# %%
# Python basic

# 4 types of data

# str
# "" or ''

# type("test example")
type(False)
# Out:
# bool

# %%
True + True + True
# Out:
# 3

# %%
#  Variables cannot start with number or with sybmol

number1 = 10
# type(number1)

name_surname = 'Tom Jackson'
# NameSurname =

# %%
len("Tom Jackson")
# Out:
# 11

# %%
name = "boris"
name.upper()
# Out:
# 'BORIS'

# %%
import pandas as pd

# pandas.read_csv()

# %%
data = pd.read_csv('AB_NYC_2019.csv')

# %%
data.shape
# Out:
# (48895, 16)

# %%
data['host_name']
# Out:
# 0                 John
# 1             Jennifer
# 2            Elisabeth
# 3          LisaRoxanne
# 4                Laura
#              ...
# 48890          Sabrina
# 48891          Marisol
# 48892    Ilgar & Aysel
# 48893              Taz
# 48894       Christophe
# Name: host_name, Length: 48895, dtype: object

# %%
data.iloc[0:3,1:3]
# Out:
#                                   name  host_id
# 0   Clean & quiet apt home by the park     2787
# 1                Skylit Midtown Castle     2845
# 2  THE VILLAGE OF HARLEM....NEW YORK !     4632

# %%
data.loc[0:3,['name','host_id']]
# Out:
#                                   name  host_id
# 0   Clean & quiet apt home by the park     2787
# 1                Skylit Midtown Castle     2845
# 2  THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3      Cozy Entire Floor of Brownstone     4869

# %%
data.iloc[[1,3],1:4]
# Out:
# 1              Skylit Midtown Castle
# 3    Cozy Entire Floor of Brownstone
# Name: name, dtype: object

# %%
data[['neighbourhood_group', 'host_name', 'host_id']]
# Out:
#       neighbourhood_group      host_name   host_id
# 0                Brooklyn           John      2787
# 1               Manhattan       Jennifer      2845
# 2               Manhattan      Elisabeth      4632
# 3                Brooklyn    LisaRoxanne      4869
# 4               Manhattan          Laura      7192
# ...                   ...            ...       ...
# 48890            Brooklyn        Sabrina   8232441
# 48891            Brooklyn        Marisol   6570630
# 48892           Manhattan  Ilgar & Aysel  23492952
# 48893           Manhattan            Taz  30985759
# 48894           Manhattan     Christophe  68119814
#
# [48895 rows x 3 columns]

# %%
data.tail(5)
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
data['price'].sum()
# Out:
# np.int64(7467278)

# %%
data.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
data.shape
# Out:
# (48895, 16)

# %%
columns_to_drop = ['id', 'host_name', 'last_review']
data.drop(columns_to_drop, axis="columns", inplace=True)

# %%
data.shape
# Out:
# (48895, 13)

# %%
data.isna().sum()
# Out:
# name                                 16
# host_id                               0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
data.isna().sum()
# Out:
# name                              16
# host_id                            0
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
data = data.dropna() # remove missing data
data.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
data.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
data.fillna({'reviews_per_month': 0}, inplace=True)

# %%
tips_df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# %%
tips_df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
tips_df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(data=tips_df,x='day',order=['Thur','Fri','Sat','Sun'])
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(data=tips_df[['day','total_bill']],x='day',order=['Thur','Fri','Sat','Sun'],)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.catplot(data=tips_df, x='day', y='total_bill', kind="box")

# %%
tips_df[['day','total_bill']].groupby('day').describe()
# Out:
#      total_bill
#           count       mean       std   min      25%    50%      75%    max
# day
# Fri        19.0  17.151579  8.302660  5.75  12.0950  15.38  21.7500  40.17
# Sat        87.0  20.441379  9.480419  3.07  13.9050  18.24  24.7400  50.81
# Sun        76.0  21.410000  8.832122  7.25  14.9875  19.63  25.5975  48.17
# Thur       62.0  17.682742  7.886170  7.51  12.4425  16.20  20.1550  43.11

# %%
tips_df.day.describe()
# Out:
# count     244
# unique      4
# top       Sat
# freq       87
# Name: day, dtype: object

# %%
sns.catplot(data=tips_df, x='day', y='total_bill', kind="boxen")

# %%
sns.pairplot(tips_df, height=2, hue="smoker")

# %%
sns.lmplot(x="total_bill", y="tip", col="smoker", data=tips_df)

# %%
with sns.axes_style(style="whitegrid"):
    sns.relplot(x="total_bill", y="tip", data=tips_df)

# %%
with sns.axes_style("white"):
    sns.jointplot(x="total_bill", y="tip", kind="hex", data=tips_df)
